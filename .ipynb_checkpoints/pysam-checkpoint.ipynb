# %%
import pysam
import pandas as pd

# %%
fetch_df = pd.read_csv('interesting_genes.bed', sep='\t', header=None, names=['chr', 'start', 'stop', 'gene'])

# %%
fetch_df
# Out:
#       chr      start       stop    gene
# 0   chr17   39688094   39728658   ERBB2
# 1   chr17   43044295   43170327   BRCA1
# 2   chr13   32315508   32400268   BRCA2
# 3   chr11  125625136  125681124   CHEK1
# 4   chr22   28687743   28741834   CHEK2
# 5    chr7   55019017   55211628    EGFR
# 6   chr17   39688094   39728658   ERBB2
# 7    chr8   38411143   38468635   FGFR1
# 8   chr10  121478330  121598458   FGFR2
# 9    chr4    1793293    1808867   FGFR3
# 10   chr7  116672196  116798377     MET
# 11   chr9   21802636   21941115    MTAP
# 12  chr12   68808172   68850686    MDM2
# 13  chr17   31094927   31377677     NF1
# 14   chr1  156815750  156881850   NTRK1
# 15  chr16   23603165   23641310   PALB2
# 16  chr13   48303751   48481890     RB1
# 17  chr19    1205778    1228431   STK11
# 18   chr9  132891349  132945378    TSC1
# 19  chr16    2047985    2089491    TSC2
# 20  chr17    7668421    7687490    TP53
# 21   chr9   21967752   21995324  CDKN2A

# %%
#pysam.index("../WES-normal.bam")

# %%
samfile = pysam.AlignmentFile('../WES-normal.bam', 'rb')
genes_bam = pysam.AlignmentFile('../genes.bam', 'wb', template=samfile)

# %%
i = 0

for index, gene in fetch_df.iterrows():
    print(gene['gene'])
    for read in samfile.fetch(gene['chr'], gene['start'], gene['stop']):
        if i == 10:
            continue
        genes_bam.write(read)

pairedreads.close()
samfile.close()
# Out:
# ERBB2
# BRCA1
# BRCA2
# CHEK1
# CHEK2
# EGFR
# ERBB2
# FGFR1
# FGFR2
# FGFR3
# MET
# MTAP
# MDM2
# NF1
# NTRK1
# PALB2
# RB1
# STK11
# TSC1
# TSC2
# TP53
# CDKN2A

# %%
samfile = pysam.AlignmentFile('../genes.bam', 'rb')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 samfile = pysam.AlignmentFile('../genes.bam', 'rb')
#
# File ~/miniconda3/envs/hahaton/lib/python3.10/site-packages/pysam/libcalignmentfile.pyx:747, in pysam.libcalignmentfile.AlignmentFile.__cinit__()
#
# File ~/miniconda3/envs/hahaton/lib/python3.10/site-packages/pysam/libcalignmentfile.pyx:957, in pysam.libcalignmentfile.AlignmentFile._open()
#
# File ~/miniconda3/envs/hahaton/lib/python3.10/site-packages/pysam/libchtslib.pyx:366, in pysam.libchtslib.HTSFile.check_truncation()
#
# OSError: no BGZF EOF marker; file may be truncated
